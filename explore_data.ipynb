# %%
import pandas as pd
import numpy as np

# %%
# Viewing 311 data
nyc_311 = pd.read_csv("nyc_311_sample.csv")
nyc_311.info
# Out:
# <bound method DataFrame.info of        unique_key             created_date agency  \
# 0        64720753  2025-04-23T01:51:16.000   NYPD
# 1        64725906  2025-04-23T01:51:14.000   NYPD
# 2        64722271  2025-04-23T01:51:09.000   NYPD
# 3        64727864  2025-04-23T01:50:41.000   NYPD
# 4        64725747  2025-04-23T01:50:06.000   NYPD
# ...           ...                      ...    ...
# 99995    64620790  2025-04-11T17:38:10.000   DSNY
# 99996    64623847  2025-04-11T17:37:51.000    HPD
# 99997    64621478  2025-04-11T17:37:47.000   NYPD
# 99998    64621068  2025-04-11T17:37:45.000   NYPD
# 99999    64619917  2025-04-11T17:37:44.000    DOB
#
#                                              agency_name  \
# 0                        New York City Police Department
# 1                        New York City Police Department
# 2                        New York City Police Department
# 3                        New York City Police Department
# 4                        New York City Police Department
# ...                                                  ...
# 99995                           Department of Sanitation
# 99996  Department of Housing Preservation and Develop...
# 99997                    New York City Police Department
# 99998                    New York City Police Department
# 99999                            Department of Buildings
#
#                        complaint_type  \
# 0                     Noise - Vehicle
# 1             Noise - Street/Sidewalk
# 2                     Illegal Parking
# 3                     Illegal Parking
# 4                            Drinking
# ...                               ...
# 99995  Residential Disposal Complaint
# 99996                       APPLIANCE
# 99997         Noise - Street/Sidewalk
# 99998                 Illegal Parking
# 99999                    Building/Use
#
#                                              descriptor         location_type  \
# 0                                       Car/Truck Music       Street/Sidewalk
# 1                                      Loud Music/Party       Street/Sidewalk
# 2                         Posted Parking Sign Violation       Street/Sidewalk
# 3                                       Blocked Hydrant       Street/Sidewalk
# 4                            After Hours - Licensed Est   Club/Bar/Restaurant
# ...                                                 ...                   ...
# 99995            Waste Left in Front of Other Residence              Sidewalk
# 99996                                ELECTRIC/GAS RANGE  RESIDENTIAL BUILDING
# 99997                                  Loud Music/Party       Street/Sidewalk
# 99998                            License Plate Obscured       Street/Sidewalk
# 99999  Illegal Conversion Of Residential Building/Space                   NaN
#
#        incident_zip           incident_address            street_name  ...  \
# 0           11208.0      2858 LINDEN BOULEVARD       LINDEN BOULEVARD  ...
# 1           11206.0         406 LORIMER STREET         LORIMER STREET  ...
# 2           11205.0  125 NORTH PORTLAND AVENUE  NORTH PORTLAND AVENUE  ...
# 3           10461.0      2873 EAST  195 STREET       EAST  195 STREET  ...
# 4           10458.0        2447 HOFFMAN STREET         HOFFMAN STREET  ...
# ...             ...                        ...                    ...  ...
# 99995       11209.0              8201 4 AVENUE               4 AVENUE  ...
# 99996       11226.0       448 EAST   26 STREET       EAST   26 STREET  ...
# 99997       10025.0       868 AMSTERDAM AVENUE       AMSTERDAM AVENUE  ...
# 99998       11375.0           108-25 72 AVENUE              72 AVENUE  ...
# 99999       11212.0       243 EAST   94 STREET       EAST   94 STREET  ...
#
#                                   resolution_description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 99995  The Department of Sanitation investigated this...
# 99996  The following complaint conditions are still o...
# 99997  The Police Department responded to the complai...
# 99998  The Police Department responded and upon arriv...
# 99999  The Department of Buildings reviewed this comp...
#
#                    closed_date taxi_pick_up_location facility_type  \
# 0                          NaN                   NaN           NaN
# 1                          NaN                   NaN           NaN
# 2                          NaN                   NaN           NaN
# 3                          NaN                   NaN           NaN
# 4                          NaN                   NaN           NaN
# ...                        ...                   ...           ...
# 99995  2025-04-12T13:47:23.000                   NaN           NaN
# 99996                      NaN                   NaN           NaN
# 99997  2025-04-11T19:17:26.000                   NaN           NaN
# 99998  2025-04-11T19:08:31.000                   NaN           NaN
# 99999  2025-04-15T00:00:00.000                   NaN           NaN
#
#       bridge_highway_name bridge_highway_direction road_ramp  \
# 0                     NaN                      NaN       NaN
# 1                     NaN                      NaN       NaN
# 2                     NaN                      NaN       NaN
# 3                     NaN                      NaN       NaN
# 4                     NaN                      NaN       NaN
# ...                   ...                      ...       ...
# 99995                 NaN                      NaN       NaN
# 99996                 NaN                      NaN       NaN
# 99997                 NaN                      NaN       NaN
# 99998                 NaN                      NaN       NaN
# 99999                 NaN                      NaN       NaN
#
#       bridge_highway_segment taxi_company_borough  due_date
# 0                        NaN                  NaN       NaN
# 1                        NaN                  NaN       NaN
# 2                        NaN                  NaN       NaN
# 3                        NaN                  NaN       NaN
# 4                        NaN                  NaN       NaN
# ...                      ...                  ...       ...
# 99995                    NaN                  NaN       NaN
# 99996                    NaN                  NaN       NaN
# 99997                    NaN                  NaN       NaN
# 99998                    NaN                  NaN       NaN
# 99999                    NaN                  NaN       NaN
#
# [100000 rows x 41 columns]>

# %%
nyc_311.head()
# Out:
#    unique_key             created_date agency  \
# 0    64720753  2025-04-23T01:51:16.000   NYPD
# 1    64725906  2025-04-23T01:51:14.000   NYPD
# 2    64722271  2025-04-23T01:51:09.000   NYPD
# 3    64727864  2025-04-23T01:50:41.000   NYPD
# 4    64725747  2025-04-23T01:50:06.000   NYPD
#
#                        agency_name           complaint_type  \
# 0  New York City Police Department          Noise - Vehicle
# 1  New York City Police Department  Noise - Street/Sidewalk
# 2  New York City Police Department          Illegal Parking
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department                 Drinking
#
#                       descriptor        location_type  incident_zip  \
# 0                Car/Truck Music      Street/Sidewalk       11208.0
# 1               Loud Music/Party      Street/Sidewalk       11206.0
# 2  Posted Parking Sign Violation      Street/Sidewalk       11205.0
# 3                Blocked Hydrant      Street/Sidewalk       10461.0
# 4     After Hours - Licensed Est  Club/Bar/Restaurant       10458.0
#
#             incident_address            street_name  ...  \
# 0      2858 LINDEN BOULEVARD       LINDEN BOULEVARD  ...
# 1         406 LORIMER STREET         LORIMER STREET  ...
# 2  125 NORTH PORTLAND AVENUE  NORTH PORTLAND AVENUE  ...
# 3      2873 EAST  195 STREET       EAST  195 STREET  ...
# 4        2447 HOFFMAN STREET         HOFFMAN STREET  ...
#
#   resolution_description closed_date taxi_pick_up_location facility_type  \
# 0                    NaN         NaN                   NaN           NaN
# 1                    NaN         NaN                   NaN           NaN
# 2                    NaN         NaN                   NaN           NaN
# 3                    NaN         NaN                   NaN           NaN
# 4                    NaN         NaN                   NaN           NaN
#
#   bridge_highway_name bridge_highway_direction road_ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   bridge_highway_segment taxi_company_borough  due_date
# 0                    NaN                  NaN       NaN
# 1                    NaN                  NaN       NaN
# 2                    NaN                  NaN       NaN
# 3                    NaN                  NaN       NaN
# 4                    NaN                  NaN       NaN
#
# [5 rows x 41 columns]

# %%
nyc_311.columns
# Out:
# Index(['unique_key', 'created_date', 'agency', 'agency_name', 'complaint_type',
#        'descriptor', 'location_type', 'incident_zip', 'incident_address',
#        'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'status', 'community_board', 'bbl', 'borough',
#        'x_coordinate_state_plane', 'y_coordinate_state_plane',
#        'open_data_channel_type', 'park_facility_name', 'park_borough',
#        'vehicle_type', 'latitude', 'longitude', 'location',
#        'resolution_action_updated_date', 'resolution_description',
#        'closed_date', 'taxi_pick_up_location', 'facility_type',
#        'bridge_highway_name', 'bridge_highway_direction', 'road_ramp',
#        'bridge_highway_segment', 'taxi_company_borough', 'due_date'],
#       dtype='object')

# %%
# Convert 'created_date' to datetime
nyc_311_clean['created_date'] = pd.to_datetime(
    nyc_311_clean['created_date'], errors='coerce'
)

# Filter for 2025 only
nyc_311_2025 = nyc_311_clean[
    nyc_311_clean['created_date'].dt.year == 2025
]

# Select only necessary columns
cols_to_keep = [
    'created_date', 'borough', 'incident_zip', 'complaint_type',
    'descriptor', 'location_type', 'agency', 'latitude', 'longitude'
]

nyc_311_filtered = nyc_311_2025[cols_to_keep].copy()

# Drop rows without incident_zip and standardize ZIP codes
nyc_311_filtered = nyc_311_filtered.dropna(subset=['incident_zip'])
nyc_311_filtered['incident_zip'] = (
    nyc_311_filtered['incident_zip'].astype(int).astype(str).str.zfill(5)
)

# Quick sanity checks
print(nyc_311_filtered['created_date'].dt.year.value_counts())
print(nyc_311_filtered['incident_zip'].unique()[:10])
print(nyc_311_filtered.info())
# Out:
# created_date
# 2025    99029
# Name: count, dtype: int64
# ['11208' '11206' '11205' '10461' '10458' '11412' '11435' '11368' '11374'
#  '11226']
# <class 'pandas.core.frame.DataFrame'>
# Index: 99029 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_date    99029 non-null  datetime64[ns]
#  1   borough         99029 non-null  object
#  2   incident_zip    99029 non-null  object
#  3   complaint_type  99029 non-null  object
#  4   descriptor      96704 non-null  object
#  5   location_type   88480 non-null  object
#  6   agency          99029 non-null  object
#  7   latitude        97812 non-null  float64
#  8   longitude       97812 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 7.6+ MB
# None

# %%
nyc_311_filtered.head()
# Out:
#          created_date   borough incident_zip           complaint_type  \
# 0 2025-04-23 01:51:16  BROOKLYN        11208          Noise - Vehicle
# 1 2025-04-23 01:51:14  BROOKLYN        11206  Noise - Street/Sidewalk
# 2 2025-04-23 01:51:09  BROOKLYN        11205          Illegal Parking
# 3 2025-04-23 01:50:41     BRONX        10461          Illegal Parking
# 4 2025-04-23 01:50:06     BRONX        10458                 Drinking
#
#                       descriptor        location_type agency   latitude  \
# 0                Car/Truck Music      Street/Sidewalk   NYPD  40.670044
# 1               Loud Music/Party      Street/Sidewalk   NYPD  40.709122
# 2  Posted Parking Sign Violation      Street/Sidewalk   NYPD  40.694353
# 3                Blocked Hydrant      Street/Sidewalk   NYPD  40.853187
# 4     After Hours - Licensed Est  Club/Bar/Restaurant   NYPD  40.857248
#
#    longitude
# 0 -73.858687
# 1 -73.948547
# 2 -73.976030
# 3 -73.832102
# 4 -73.887390

# %%
print("First date:", nyc_311_filtered['created_date'].min())
print("Last date:", nyc_311_filtered['created_date'].max())
# Out:
# First date: 2025-04-11 17:37:44
# Last date: 2025-04-23 01:51:16
